# %%
import random        # importing random 
import time          # handles various functions regarding time
from sys import exit # module system takes exit function

"""
Created on Sat Oct 23 9:52:46 2021

@author: Sonish Raj
"""

"""
    DocString:
    
    A) Introduction:
    This game is based on the crime thiller.It consists of three levels, and also has defined functions
    for story,play and levels. Please read the game before you begin play. Here you can find the story
    https://yourstoryclub.com/short-stories-suspense-thriller/psychological-thriller-short-story-i-am-murderer/index.html
    
    Level 1: Decide whether characters names.
    Level 2: Going to home
    Level 3: Finding dead bodies
    
    B) Known Bugs and/or Errors:
    None.
    
"""

#This function has complete story.
def story():
    for i in range(0, 60): # adding a conditional to the for loop
        print('*', end=" ")
    print("\n")
    print("""The beautiful lady of about 22 or 23 years, had long hairs which were maintained really nicely, wearing pink shirt and 
        dark blue jeans, had sunglasses on her eyes. She was looking from a nice and rich family.
        She was sitting in our police station, opposite to my table. I was the in charge of the police station.
        I asked her “What happened to you?” She told we are 4 in a family, 3 people are killed they are my Gardner, my driver 
        and ……..” She paused a bit and started to sob. “And my mother.” She started crying hard. When she controlled her emotions, 
        she continued to talk. “Please I beg of you, please arrest them.

        What’s your name?” 
        “Shilpa, why did you kill them?”

        “I don’t know. I just happened automatically.”

        “Shilpa, I am not getting it. And I cannot arrest without any complaint and without seeing the body of the dead people you are 
        talking about.” She was looking very tense to me. So I continued, “Shilpa, where are the bodies?”

        “The bodies are dug them in my garden.”
        I decided to go to her house. I took two constables also with me. When we reached her house she took us to her garden and 
        told us the places where the body of the gardener and driver were dug. I commanded the constables to take the bodies out.
        “Where’s the body of your mother?” I asked Shilpa.

        “Inside the home.”
        I started to follow Shilpa. She took me inside the house and then stopped in front of a dark room.
        “Inside. My mother is lying inside.” She started to cry again.

        I slowly started to move inside the room. The room was so dark that it was difficult to see anything. I had one torch with me 
        so I decided to turn that on. I searched the whole room but the room was empty. Then I saw one room which was closed.
        I opened that room. And got shocked to see that there were three bodies lying inside the room. Two men may be Shilpa’s gardener
        and driver and one old lady may be her mother. I was wondering why Shilpa told me that bodies are out there in garden.

        “Ahhhhhh………” Someone stabbed me from behind. I turned around. I was shocked to see Shilpa standing with a knife in her right 
        hand covered with blood of mine.
        “Why?” I asked her in a trembling voice.

        She came closer to me and stabbed in my stomach and said, “Because, it’s fun.”
        I fell on ground and she took my gun and rushed outside. I heard two fires. She killed my constables also

        __END__

        """)

# This function has 1 argument
def read_story(fromLevel): 
    
    story() #this function calls story function
    print("\n")
    #takin input as string. to check the user has read the story or not. if user types exit; it's quits the game
    answer=input(prompt = "Have you Read the story: please type yes or no: (Enter Exit to exit the game) \n")
    
    if answer.lower()=='yes': # creating a condition
        if fromLevel == 1:
          play() 
        if fromLevel == 2:
          level_2() 
    elif answer.lower()=='no':  #if user types 'no' its calls read_story() function
        read_story(1)
    elif answer.lower()=='exit': #if user types exit: it quits the program
        quit(True)
    else:
        print("Invalid entry. You are out of game")
         
def play(): #This function calls only user is read the story   
    print("Let's begin the game ....")
    print("Game in 2 Seconds")
    time.sleep(2) #this function suspends execution of current thread for given number of seconds
    level_1()
    
def level1():
    my_list = [level1_Question_1,level1_Question_2,level1_Question_3]
    random.choice(my_list)()

    ans1 = my_list[0]
    ans2 = my_list[1]
    ans3 = my_list[2]
    if ans1 == my_list[0]:
        level1_Question_1()
        score = 0;
        if ans1.lower() == 'shilpa':
            score+=1
    level2_Question_2()
    level3_Question_3()
    
    
#defined functions for level 1 questions 
def level1_Question_1():
    print("")
    print("-----------Question 1 ------------------\n")
    sq2=True
    while sq2:
        print("What's name of the Young Lady?\n")
        ans1= input(prompt = ">")
        if ans1.lower()=='shilpa': #user has to enter correct input otherwise it calls read_story()
            return ans1
        else:
            print("wrong answer. Read the story again\n")
            time.sleep(2)
            read_story(1)

#defined functions for level 1 questions 
def level1_Question_2():
    print("")
    print("-----------Question 2 ------------------\n")
    sq2= True 
    while sq2: #while loop; it calls again and again until user types valid input
      print("Where she was sitting? \n")
      print("Choose One Option")
      print("1.House")
      print("2.Police station")
      print("3.Park\n")
      ans2= input(prompt = ">")
      if ans2 == '1' or ans2 == '2' or ans2 == '3' or ans2.lower() == 'police station' or ans2.lower() == 'policestation':
        return ans2
      else:
        print("Wrong Option Choose numbers  (eg. 1 or 2) or enter the correct answer  \n")
        sq2 = True
        
#defined functions for level 1 questions 
def level1_Question_3():
    print("")
    print("-----------Question 3 ------------------\n")
    sq2= True
    while sq2:  #while loop; it calls again and again until user types valid input
        print("How many pepole were killed at Shilpa's home?\n ")
        print("Choose One Option")
        print("1.Four")
        print("2.Three")
        print("3.Five\n")
        ans3= input(prompt = ">")
        if ans3 == '1' or ans3 == '2' or ans3 == '3' or ans3.lower() == 'three':
            return ans3
        else:
            print("Wrong Option Choose numbers  (eg. 1 or 2) or enter the correct answer  \n")
            sq2 = True
            
            
            
def level2_Question_1():
    print("")
    print("Welcome to Level 2\n ")
    time.sleep(2) #this function suspends execution of current thread for given number of seconds
    print("")
    print("-----------Question 1 ------------------\n")
    sq2= True
    while sq2:  #while loop; it calls again and again until user types valid input
        print("How may pepole went with Shilpa to their home ?\n ")
        print("Choose One Option ")
        print("1.Three")
        print("2.Four")
        print("3.Two\n")
        ans1= input(prompt = ">")
        if ans1 =='1' or ans1 == '2' or ans1 == '3' or ans1.lower() == 'three':
            return ans1
        else:
            print("Wrong Option Choose numbers  (eg. 1 or 2) or enter the correct answer  \n")
            sq2 = True
            
def level2_Question_2():
    print("")
    print("-----------Question 2 ------------------\n")
    sq2= True
    while sq2:  #while loop; it calls again and again until user types valid input
        print("How may bodies are there in garden ?\n ")
        print("Choose One Option")
        print("1.Two")
        print("2.Three")
        print("3.Four\n")
        ans2= input(prompt = ">")
        if ans2 =='1' or ans2 == '2' or ans2 == '3' or ans2.lower() == 'two':
            return ans2
        else:
            print("Wrong Option Choose numbers  (eg. 1 or 2) or enter the correct answer  \n")
            sq2 = True
            
def level2_Question_3():
    print("")
    print("-----------Question 3 ------------------\n")
    sq2= True
    while sq2:  #while loop; it calls again and again until user types valid input
        print("Where is your mother body\n ?")
        print("Choose One Option")
        print("1.Garden")
        print("2.Hall")
        print("3.Room\n")
        ans3= input(prompt = ">")
        if ans3 =='1' or ans3 == '2' or ans3 == '3' or ans3.lower() == 'room':
            return ans3
        else:
            print("Wrong Option Choose numbers  (eg. 1 or 2) or enter the correct answer  \n")
            sq2 = True
        
        
def level3_Question_1():
    print("")
    print("Welcome to Level 3\n ")
    time.sleep(2)
    print("-----------Question 1 ------------------\n")
    print("Are you willing to enter to Dark room?\n ")
    print("Choose One Option")
    print("1.Yes")
    print("2.No\n")
    ans1= input(prompt = ">")
    return ans1
      
            
def level3_Question_2():
    print("")
    print("-----------Question 2 ------------------\n")
    sq2= True
    while sq2:  #while loop; it calls again and again until user types valid input
        print("How may bodies are there in Dark room?\n")
        print("Choose One Option")
        print("1.Two")
        print("2.Three")
        print("3.Four\n")
        ans2= input(prompt = ">")
        if ans2 =='1' or ans2 == '2' or ans2 == '3' or ans2.lower() == 'three':
            return ans2
        else:
            print("Wrong Option Choose numbers  (eg. 1 or 2) or enter the correct answer \n ")
            sq2 = True
            
def level3_Question_3():
    print("")
    print("-----------Question 3 ------------------\n")
    print("Who stabbed policeman?\n")
    ans3= input(prompt = ">")
    return ans3

def level3_Question_4():
    print("")
    print("-----------Question 4 ------------------\n")
    print("Who is the criminal in this story? \n")
    ans4= input(prompt = ">")
    return ans4


def level_1():
    MIN_SCORE = 2 #variable MIN_SCORE holds value 2 
    
    level1()
    
    

    if ans2 == '2' or ans2.lower() == 'police station' or ans2.lower() == 'policestation':
        score+=1
        
    if ans3 == '2' or ans3.lower() == 'three':
        score+=1;
    
    if score < MIN_SCORE: #if score is less than 2 read the story or goto next level
        print("Your Score is: " + str(score))
        print("\n")
        print("You are not Eligible to Next Level \n")
        print("Pleae Read the story Again...")
        read_story(1)

    else:
        print("Level 1 Completed")
        print("Your Level 1 Score is " + str(score))
        level_2() #satrts executing level 2 

def level_2():
    MIN_SCORE = 2 #variable MIN_SCORE holds value 2 
    ans1 = level2_Question_1()
    ans2 = level2_Question_2()
    ans3 = level2_Question_3()
    
        
    score = 0;
    if ans1 == '1' or ans1.lower() == 'three':
        score+=1

    if ans2 == '1' or ans2.lower() == 'two':
        score+=1
        
    if ans3 == '3' or ans3.lower() == 'room':
        score+=1;
    #if score is less than 2 read the story or goto next level
    if score < MIN_SCORE:
        print("Your Score is: " + str(score))
        print("\n")
        print("You are not Eligible to Next Level \n")
        print("Pleae Read the story Again...")
        read_story(2)

    else:
        print("Level 2 Completed")
        print("Your Level 2 Score is " + str(score))
        level_3()
        
def level_3():
    show_ques=True
    score = 0;
    MIN_SCORE = 2
    #if user selects '1' or 'yes' it will go to 2nd question. else it exceute except condition.
    try:
        ans1 = level3_Question_1()
        if ans1 == '1' or ans1.lower()=='yes':
            score+=1
        else:
            print("Wrong Option Selected Choose numbers  (eg. 1 or 2) or enter the correct answer \n")
            exit() #exits from the game if user not entering dark room
    except: 
        show_ques=False
        thankyou() #this function calls only if user not willing to enter dark room
        
        
    if show_ques:    
        ans2 = level3_Question_2()

        if ans2 == '2' or ans2.lower() == 'three':
            score+=1
            
        ans3 = level3_Question_3()
        
        if ans3.lower() == 'shilpa':
            score+=1
            
        ans4 = level3_Question_4()
        
        if ans4.lower() == 'shilpa':
            score+=1
        
        print("")
        print("Level 3 Completed\n")
        print("Your Level 3 Score is " + str(score))
        print("")
        print("Thanks for playing")
        
def thankyou():
    print("Thanks for playing")
    quit(True)

start = True
while start: #while loop excutes until it is true.
  name = input(prompt = 'Enter your name:') # Specifying prompt

   #strip() removes all leading and trailing spaces. Here len() use calucalte the length.
  if len(name.strip()) > 0 : #it checks user has to enter name
    print(f"Welcome {name} to play the crime thriller game\n")
    time.sleep(2)
    print(" ")
    # user input
    print('Before playing the game. Can you guess the number?')
    guess = input(prompt = 'Pick a number between 1 and 10.\n')

    # turning guess into an integer
    guess = int(guess)

    # generating a random number
    number = random.randint(a = 1,
                            b = 10)

    print(f"""
    Did you guess correctly (True/False)?
    {guess == number}

    I was thinking of the number {number}!
    """)
    time.sleep(3)
    read_story(1) # calling read_story()
    start = False
  else:
    print("Name Cannot be Empty. Please type your name ") # printing if user not entered name
    start = True
